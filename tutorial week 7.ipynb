# %% [markdown]
# Ingest image data and check the basic properties of the image

# %%
from PIL import Image, ExifTags
import matplotlib.pyplot as plt
#charlie chaplin was a  british comic actor, well know by virtually everyone.
#we will be loading his picture from BB
chaplin = Image.open("/content/Chaplin.png")

# %%
chaplin
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=512x619>
